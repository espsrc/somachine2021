# %% [markdown]
# # SOMACHINE 2020
# ## Machine Learning, Big Data, and Deep Learning in Astronomy
# -----
# ### A Severo Ochoa School of the Instituto de Astrofísica de Andalucía (CSIC)
#
# ![SOMACHINE](SOMACHINE_LOGOS.png)
#
# ### Workshop Tutorials
#
# - **Practical ML: Scikit-learn**  (Juan Antonio Cortés, UGR)
#   - [Practical ML: Scikit-learn](./tutorial_01_ML/tutorial_01_ML.ipynb)
# - **Practical DL with Keras: A Quick Glance** (Alberto Castillo, UGR)
#    - [Practical Deep Learning_ A quick glance (slides)](./tutorial_04_DL_keras/Practical%20Deep%20Learning_%20A%20quick%20glance.pdf)
#    - [Data preparation](./tutorial_04_DL_keras/galaxy_data_preparation.ipynb)
#    - [Galaxy Classification](./tutorial_04_DL_keras/galaxy_classification.ipynb)
